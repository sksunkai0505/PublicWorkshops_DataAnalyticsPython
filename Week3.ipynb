# %%
# to handle datasets
import pandas as pd
import numpy as np

# %%
link = 'C:/Users/sksun/Desktop/DAwithPython/CleanRentDataWeek2InClass.csv'
data = pd.read_csv(link)
data.shape
# Out:
# (263771, 22)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'url', 'region', 'region_url', 'price', 'type',
#        'sqfeet', 'beds', 'baths', 'cats_allowed', 'dogs_allowed',
#        'smoking_allowed', 'wheelchair_access', 'electric_vehicle_charge',
#        'comes_furnished', 'laundry_options', 'parking_options', 'image_url',
#        'lat', 'long', 'state'],
#       dtype='object')

# %%
del data[data.columns[0]]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263771 entries, 0 to 263770
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       263771 non-null  int64
#  1   url                      263771 non-null  object
#  2   region                   263771 non-null  object
#  3   region_url               263771 non-null  object
#  4   price                    263771 non-null  int64
#  5   type                     263771 non-null  object
#  6   sqfeet                   263771 non-null  int64
#  7   beds                     263771 non-null  int64
#  8   baths                    263771 non-null  float64
#  9   cats_allowed             263771 non-null  int64
#  10  dogs_allowed             263771 non-null  int64
#  11  smoking_allowed          263771 non-null  int64
#  12  wheelchair_access        263771 non-null  int64
#  13  electric_vehicle_charge  263771 non-null  int64
#  14  comes_furnished          263771 non-null  int64
#  15  laundry_options          209644 non-null  object
#  16  parking_options          169327 non-null  object
#  17  image_url                263771 non-null  object
#  18  lat                      263771 non-null  float64
#  19  long                     263771 non-null  float64
#  20  state                    263771 non-null  object
# dtypes: float64(3), int64(10), object(8)
# memory usage: 42.3+ MB

# %%
del data[data.columns[0]]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263771 entries, 0 to 263770
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   url                      263771 non-null  object
#  1   region                   263771 non-null  object
#  2   region_url               263771 non-null  object
#  3   price                    263771 non-null  int64
#  4   type                     263771 non-null  object
#  5   sqfeet                   263771 non-null  int64
#  6   beds                     263771 non-null  int64
#  7   baths                    263771 non-null  float64
#  8   cats_allowed             263771 non-null  int64
#  9   dogs_allowed             263771 non-null  int64
#  10  smoking_allowed          263771 non-null  int64
#  11  wheelchair_access        263771 non-null  int64
#  12  electric_vehicle_charge  263771 non-null  int64
#  13  comes_furnished          263771 non-null  int64
#  14  laundry_options          209644 non-null  object
#  15  parking_options          169327 non-null  object
#  16  image_url                263771 non-null  object
#  17  lat                      263771 non-null  float64
#  18  long                     263771 non-null  float64
#  19  state                    263771 non-null  object
# dtypes: float64(3), int64(9), object(8)
# memory usage: 40.2+ MB

# %%
# Getting appropriate data types. 
# For example baths have a dtype of float, 
# and it contains some decimal values. 
# But it is a quantitative variable. So transforming it to remove decimal.

# %%
# data['baths'] = np.ceil(data['baths'])
# 2.5 bath 
# ceiling function 
np.ceil(3.6)
# Out:
# 4.0

# %%
data['baths'] = np.ceil(data['baths'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263771 entries, 0 to 263770
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   url                      263771 non-null  object
#  1   region                   263771 non-null  object
#  2   region_url               263771 non-null  object
#  3   price                    263771 non-null  int64
#  4   type                     263771 non-null  object
#  5   sqfeet                   263771 non-null  int64
#  6   beds                     263771 non-null  int64
#  7   baths                    263771 non-null  float64
#  8   cats_allowed             263771 non-null  int64
#  9   dogs_allowed             263771 non-null  int64
#  10  smoking_allowed          263771 non-null  int64
#  11  wheelchair_access        263771 non-null  int64
#  12  electric_vehicle_charge  263771 non-null  int64
#  13  comes_furnished          263771 non-null  int64
#  14  laundry_options          209644 non-null  object
#  15  parking_options          169327 non-null  object
#  16  image_url                263771 non-null  object
#  17  lat                      263771 non-null  float64
#  18  long                     263771 non-null  float64
#  19  state                    263771 non-null  object
# dtypes: float64(3), int64(9), object(8)
# memory usage: 40.2+ MB

# %%
# change the data type as integer 
data['baths'] = data['baths'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263771 entries, 0 to 263770
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   url                      263771 non-null  object
#  1   region                   263771 non-null  object
#  2   region_url               263771 non-null  object
#  3   price                    263771 non-null  int64
#  4   type                     263771 non-null  object
#  5   sqfeet                   263771 non-null  int64
#  6   beds                     263771 non-null  int64
#  7   baths                    263771 non-null  int32
#  8   cats_allowed             263771 non-null  int64
#  9   dogs_allowed             263771 non-null  int64
#  10  smoking_allowed          263771 non-null  int64
#  11  wheelchair_access        263771 non-null  int64
#  12  electric_vehicle_charge  263771 non-null  int64
#  13  comes_furnished          263771 non-null  int64
#  14  laundry_options          209644 non-null  object
#  15  parking_options          169327 non-null  object
#  16  image_url                263771 non-null  object
#  17  lat                      263771 non-null  float64
#  18  long                     263771 non-null  float64
#  19  state                    263771 non-null  object
# dtypes: float64(2), int32(1), int64(9), object(8)
# memory usage: 39.2+ MB

# %%
# missing values
# laundry_options 
# parking_options
# make a list of the categorical variables that contain missing values
cat_var_na = ['laundry_options', 'parking_options']

# %%
# where is missing?
# maybe only certain type of rentals has missing values?
# we will need to assign a value to the missing values based on the rtental types 
# we will need a lambda fucntion to do someething with the data 
# based on certain conditions

# %%
# lambda fucniton define a certain condition, 
# with what we want to do with this condition

# %%
# before we go to the lambda function,
# let us see some details in the group by function
groupeData = data.groupby('type', group_keys=False)['laundry_options']
groupeData

# %%
groupeData.apply(pd.DataFrame)
# Out:
#               apartment assisted living condo cottage/cabin duplex flat house  \
# 0       laundry on site             NaN   NaN           NaN    NaN  NaN   NaN
# 1       laundry on site             NaN   NaN           NaN    NaN  NaN   NaN
# 2       laundry on site             NaN   NaN           NaN    NaN  NaN   NaN
# 3       laundry on site             NaN   NaN           NaN    NaN  NaN   NaN
# 4       laundry on site             NaN   NaN           NaN    NaN  NaN   NaN
# ...                 ...             ...   ...           ...    ...  ...   ...
# 263766      w/d in unit             NaN   NaN           NaN    NaN  NaN   NaN
# 263767      w/d in unit             NaN   NaN           NaN    NaN  NaN   NaN
# 263768      w/d hookups             NaN   NaN           NaN    NaN  NaN   NaN
# 263769              NaN             NaN   NaN           NaN    NaN  NaN   NaN
# 263770      w/d hookups             NaN   NaN           NaN    NaN  NaN   NaN
#
#        in-law land loft manufactured townhouse
# 0         NaN  NaN  NaN          NaN       NaN
# 1         NaN  NaN  NaN          NaN       NaN
# 2         NaN  NaN  NaN          NaN       NaN
# 3         NaN  NaN  NaN          NaN       NaN
# 4         NaN  NaN  NaN          NaN       NaN
# ...       ...  ...  ...          ...       ...
# 263766    NaN  NaN  NaN          NaN       NaN
# 263767    NaN  NaN  NaN          NaN       NaN
# 263768    NaN  NaN  NaN          NaN       NaN
# 263769    NaN  NaN  NaN          NaN       NaN
# 263770    NaN  NaN  NaN          NaN       NaN
#
# [263771 rows x 12 columns]

# %%
# we assume that only certain type of rentals has missing values
# we want to know the number of missing values of each type of rentals
DefineTheLambda = lambda x: x.isnull().sum()
data.groupby('type', group_keys=False)['laundry_options'].apply(DefineTheLambda)
# Out:
# type
# apartment          45995
# assisted living        0
# condo                798
# cottage/cabin         64
# duplex               198
# flat                  16
# house               6390
# in-law                15
# land                   0
# loft                  14
# manufactured         113
# townhouse            524
# Name: laundry_options, dtype: int64

# %%
data["laundry_options"].unique()
# Out:
# array(['laundry on site', 'w/d hookups', 'w/d in unit', nan,
#        'laundry in bldg', 'no laundry on site'], dtype=object)

# %%
AsTheFirstInMode = lambda x: x.fillna(x.mode().iloc[0])

# %%
data.groupby("type", group_keys=False)["laundry_options"].apply(AsTheFirstInMode)
# Out:
# 0         laundry on site
# 1         laundry on site
# 2         laundry on site
# 3         laundry on site
# 4         laundry on site
#                ...
# 263766        w/d in unit
# 263767        w/d in unit
# 263768        w/d hookups
# 263769        w/d in unit
# 263770        w/d hookups
# Name: laundry_options, Length: 263771, dtype: object

# %%
data["laundry_options"].unique()
# Out:
# array(['laundry on site', 'w/d hookups', 'w/d in unit', nan,
#        'laundry in bldg', 'no laundry on site'], dtype=object)

# %%
def imputeMissingCatData(df, MIssingDatacolName, modeBaseOn):
    CatDataLambda = lambda x: x.fillna(x.mode().iloc[0])
    output = data.groupby(modeBaseOn, 
                          group_keys=False)[MIssingDatacolName].apply(CatDataLambda)
    return output

# %%
data["laundry_options"] = imputeMissingCatData(data, "laundry_options", "type")
data.head(14)
# Out:
#                                                   url      region  \
# 0   https://bham.craigslist.org/apa/d/birmingham-h...  birmingham
# 1   https://bham.craigslist.org/apa/d/birmingham-w...  birmingham
# 2   https://bham.craigslist.org/apa/d/birmingham-g...  birmingham
# 3   https://bham.craigslist.org/apa/d/birmingham-f...  birmingham
# 4   https://bham.craigslist.org/apa/d/birmingham-2...  birmingham
# 5   https://bham.craigslist.org/apa/d/birmingham-s...  birmingham
# 6   https://bham.craigslist.org/apa/d/birmingham-2...  birmingham
# 7   https://bham.craigslist.org/apa/d/calera-st-av...  birmingham
# 8   https://bham.craigslist.org/apa/d/birmingham-n...  birmingham
# 9   https://bham.craigslist.org/apa/d/birmingham-a...  birmingham
# 10  https://bham.craigslist.org/apa/d/birmingham-o...  birmingham
# 11  https://bham.craigslist.org/apa/d/birmingham-t...  birmingham
# 12  https://bham.craigslist.org/apa/d/birmingham-p...  birmingham
# 13  https://bham.craigslist.org/apa/d/birmingham-1...  birmingham
#
#                      region_url  price       type  sqfeet  beds  baths  \
# 0   https://bham.craigslist.org   1195  apartment    1908     3      2
# 1   https://bham.craigslist.org   1120  apartment    1319     3      2
# 2   https://bham.craigslist.org    825  apartment    1133     1      2
# 3   https://bham.craigslist.org    800  apartment     927     1      1
# 4   https://bham.craigslist.org    785  apartment    1047     2      1
# 5   https://bham.craigslist.org    900  apartment    1298     2      2
# 6   https://bham.craigslist.org    925  apartment    1350     2      2
# 7   https://bham.craigslist.org   1085      house    2308     3      2
# 8   https://bham.craigslist.org   1269  apartment    1156     3      2
# 9   https://bham.craigslist.org    799  apartment     703     1      1
# 10  https://bham.craigslist.org    890  apartment    1050     2      2
# 11  https://bham.craigslist.org   1355  apartment    1375     3      2
# 12  https://bham.craigslist.org   1120  apartment    1319     3      2
# 13  https://bham.craigslist.org    685      house     672     2      1
#
#     cats_allowed  dogs_allowed  smoking_allowed  wheelchair_access  \
# 0              1             1                1                  0
# 1              1             1                1                  0
# 2              1             1                1                  0
# 3              1             1                1                  0
# 4              1             1                1                  0
# 5              1             1                1                  0
# 6              1             1                1                  0
# 7              1             1                0                  0
# 8              1             1                1                  0
# 9              1             1                1                  0
# 10             0             0                1                  0
# 11             1             1                1                  0
# 12             1             1                1                  0
# 13             1             1                0                  0
#
#     electric_vehicle_charge  comes_furnished  laundry_options  \
# 0                         0                0  laundry on site
# 1                         0                0  laundry on site
# 2                         0                0  laundry on site
# 3                         0                0  laundry on site
# 4                         0                0  laundry on site
# 5                         0                0  laundry on site
# 6                         0                0  laundry on site
# 7                         0                0      w/d hookups
# 8                         0                0      w/d in unit
# 9                         0                0      w/d in unit
# 10                        0                0      w/d in unit
# 11                        0                0      w/d hookups
# 12                        0                0  laundry on site
# 13                        0                0      w/d hookups
#
#        parking_options                                          image_url  \
# 0       street parking  https://images.craigslist.org/00L0L_80pNkyDeG0...
# 1   off-street parking  https://images.craigslist.org/00707_uRrY9CsNMC...
# 2       street parking  https://images.craigslist.org/00h0h_b7Bdj1NLBi...
# 3       street parking  https://images.craigslist.org/00808_6ghZ8tSRQs...
# 4       street parking  https://images.craigslist.org/00y0y_21c0FOvUXm...
# 5       street parking  https://images.craigslist.org/00606_g79izH5xxk...
# 6       street parking  https://images.craigslist.org/00505_cAu36QXQV4...
# 7                  NaN  https://images.craigslist.org/00D0D_g4BE3jPMBr...
# 8                  NaN  https://images.craigslist.org/00a0a_lTBiptw032...
# 9                  NaN  https://images.craigslist.org/00707_9dHoTSYoQn...
# 10                 NaN  https://images.craigslist.org/00F0F_dUuX9IjtBo...
# 11  off-street parking  https://images.craigslist.org/00e0e_3dpp7INsfO...
# 12  off-street parking  https://images.craigslist.org/00B0B_dEBInk4ZGf...
# 13             carport  https://images.craigslist.org/00i0i_jQUVEgjU4k...
#
#         lat     long state
# 0   33.4226 -86.7065    al
# 1   33.3755 -86.8045    al
# 2   33.4226 -86.7065    al
# 3   33.4226 -86.7065    al
# 4   33.4226 -86.7065    al
# 5   33.4226 -86.7065    al
# 6   33.4226 -86.7065    al
# 7   33.0969 -86.7601    al
# 8   33.4237 -86.8015    al
# 9   33.4237 -86.8015    al
# 10  33.4326 -86.7055    al
# 11  33.4283 -86.7183    al
# 12  33.3755 -86.8045    al
# 13  33.5755 -86.8856    al

# %%
data["parking_options"] = imputeMissingCatData(data, "parking_options", "type")

# %%
data["laundry_options"].unique()
# Out:
# array(['laundry on site', 'w/d hookups', 'w/d in unit', 'laundry in bldg',
#        'no laundry on site'], dtype=object)

# %%
#Check remaining missing values if any 
all_data_na = (data.isnull().sum() / len(data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head()
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
#Check remaining missing values if any 
link = 'C:/Users/sksun/Desktop/DAwithPython/CleanRentDataWeek2InClass.csv'
OriginalData = pd.read_csv(link)

all_data_na = (OriginalData.isnull().sum() / len(data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head()
# Out:
#                  Missing Ratio
# parking_options      35.805301
# laundry_options      20.520451

# %%
# missing value problem resolved

# %%
# deal with outliers

# %%
def out_iqr(df , column):
    q25 = np.quantile(df[column], 0.25)
    q75 = np.quantile(df[column], 0.75)
    # calculate the IQR
    iqr = q75 - q25
    # calculate the outlier cutoff
    cut_off = iqr * 1.5
    # calculate the lower and upper bound value
    lower = q25 - cut_off
    upper = q75 + cut_off
    print('The IQR is',iqr)
    print('The lower bound value is', lower)
    print('The upper bound value is', upper)
    # Calculate the number of records below and above lower and above bound value respectively
    df1 = df[df[column] > upper]
    df2 = df[df[column] < lower]
    return print('Total number of outliers are', df1.shape[0]+ df2.shape[0])

# %%
out_iqr(data, 'price')
# Out:
# The IQR is 632.0
# The lower bound value is -130.0
# The upper bound value is 2398.0
# Total number of outliers are 13387

# %%
out_iqr(data,'sqfeet')
# Out:
# The IQR is 402.0
# The lower bound value is 149.0
# The upper bound value is 1757.0
# Total number of outliers are 11025

# %%
out_iqr(data,'beds')
# Out:
# The IQR is 1.0
# The lower bound value is -0.5
# The upper bound value is 3.5
# Total number of outliers are 9908

# %%
out_iqr(data,'baths')
# Out:
# The IQR is 1.0
# The lower bound value is -0.5
# The upper bound value is 3.5
# Total number of outliers are 2084

# %%
price_upper, price_lower = 2398, 1
sqfeet_upper, sqfeet_lower = 1757, 1
beds_upper, beds_lower = 4, 1
baths_upper, baths_lower = 4, 1

data = data[(data['price'] <= price_upper) & (data['price'] >= price_lower)]
data = data[(data['sqfeet'] <= sqfeet_upper) & (data['sqfeet'] >= sqfeet_lower)]
data = data[(data['beds'] <= beds_upper) & (data['beds'] >= beds_lower)]
data = data[(data['baths'] <= baths_upper) & (data['baths'] >= baths_lower)]

# %%
data.shape
# Out:
# (232298, 20)

# %%
# adding new cols 
data['premium_house'] = np.where((data['baths']>=data['beds'])&(data['beds']>1),1,0)

# %%
data['pets_allowed'] = np.where((data['cats_allowed']==1)&data['dogs_allowed']==1,1,0)
data['beds_per_sqfeet'] = data['beds'] / data['sqfeet']
data['baths_per_beds'] = data['baths'] / data['beds']

# %%
data.columns
# Out:
# Index(['url', 'region', 'region_url', 'price', 'type', 'sqfeet', 'beds',
#        'baths', 'cats_allowed', 'dogs_allowed', 'smoking_allowed',
#        'wheelchair_access', 'electric_vehicle_charge', 'comes_furnished',
#        'laundry_options', 'parking_options', 'image_url', 'lat', 'long',
#        'state', 'premium_house', 'pets_allowed', 'beds_per_sqfeet',
#        'baths_per_beds'],
#       dtype='object')

# %%
data
# Out:
#                                                       url      region  \
# 1       https://bham.craigslist.org/apa/d/birmingham-w...  birmingham
# 2       https://bham.craigslist.org/apa/d/birmingham-g...  birmingham
# 3       https://bham.craigslist.org/apa/d/birmingham-f...  birmingham
# 4       https://bham.craigslist.org/apa/d/birmingham-2...  birmingham
# 5       https://bham.craigslist.org/apa/d/birmingham-s...  birmingham
# ...                                                   ...         ...
# 263765  https://columbus.craigslist.org/apa/d/columbus...    columbus
# 263766  https://columbus.craigslist.org/apa/d/columbus...    columbus
# 263768  https://columbus.craigslist.org/apa/d/grove-ci...    columbus
# 263769  https://columbus.craigslist.org/apa/d/columbus...    columbus
# 263770  https://columbus.craigslist.org/apa/d/newark-l...    columbus
#
#                              region_url  price       type  sqfeet  beds  \
# 1           https://bham.craigslist.org   1120  apartment    1319     3
# 2           https://bham.craigslist.org    825  apartment    1133     1
# 3           https://bham.craigslist.org    800  apartment     927     1
# 4           https://bham.craigslist.org    785  apartment    1047     2
# 5           https://bham.craigslist.org    900  apartment    1298     2
# ...                                 ...    ...        ...     ...   ...
# 263765  https://columbus.craigslist.org    870  apartment     933     2
# 263766  https://columbus.craigslist.org    929  apartment     728     1
# 263768  https://columbus.craigslist.org   1069  apartment    1020     2
# 263769  https://columbus.craigslist.org   1507  apartment    1660     2
# 263770  https://columbus.craigslist.org   1001  apartment    1220     3
#
#         baths  cats_allowed  dogs_allowed  ...  laundry_options  \
# 1           2             1             1  ...  laundry on site
# 2           2             1             1  ...  laundry on site
# 3           1             1             1  ...  laundry on site
# 4           1             1             1  ...  laundry on site
# 5           2             1             1  ...  laundry on site
# ...       ...           ...           ...  ...              ...
# 263765      2             1             1  ...      w/d hookups
# 263766      1             1             1  ...      w/d in unit
# 263768      2             1             1  ...      w/d hookups
# 263769      2             1             1  ...      w/d in unit
# 263770      2             1             1  ...      w/d hookups
#
#            parking_options                                          image_url  \
# 1       off-street parking  https://images.craigslist.org/00707_uRrY9CsNMC...
# 2           street parking  https://images.craigslist.org/00h0h_b7Bdj1NLBi...
# 3           street parking  https://images.craigslist.org/00808_6ghZ8tSRQs...
# 4           street parking  https://images.craigslist.org/00y0y_21c0FOvUXm...
# 5           street parking  https://images.craigslist.org/00606_g79izH5xxk...
# ...                    ...                                                ...
# 263765      street parking  https://images.craigslist.org/00G0G_3wSexhiMcr...
# 263766  off-street parking  https://images.craigslist.org/00v0v_cE9ismC2Ad...
# 263768     detached garage  https://images.craigslist.org/00N0N_ioCvFNCv24...
# 263769  off-street parking  https://images.craigslist.org/00j0j_5EIRWzdHCV...
# 263770  off-street parking  https://images.craigslist.org/00J0J_6VSTqFJb86...
#
#             lat     long state premium_house  pets_allowed  beds_per_sqfeet  \
# 1       33.3755 -86.8045    al             0             1         0.002274
# 2       33.4226 -86.7065    al             0             1         0.000883
# 3       33.4226 -86.7065    al             0             1         0.001079
# 4       33.4226 -86.7065    al             0             1         0.001910
# 5       33.4226 -86.7065    al             1             1         0.001541
# ...         ...      ...   ...           ...           ...              ...
# 263765  39.8971 -82.8957    oh             1             1         0.002144
# 263766  39.9709 -82.9241    oh             0             1         0.001374
# 263768  39.8408 -83.0804    oh             1             1         0.001961
# 263769  40.0564 -83.0417    oh             1             1         0.001205
# 263770  40.0451 -82.4564    oh             0             1         0.002459
#
#        baths_per_beds
# 1            0.666667
# 2            2.000000
# 3            1.000000
# 4            0.500000
# 5            1.000000
# ...               ...
# 263765       1.000000
# 263766       1.000000
# 263768       1.000000
# 263769       1.000000
# 263770       0.666667
#
# [232298 rows x 24 columns]

# %%
# Numerical variable transformation
# We will log transform the positive numerical variables 
# in order to get a more Gaussian-like distribution. 
# the process is called Power Transforms
# This tends to help Linear machine learning models.

# %%
# the distribution may be exponential, 
# but may look normal if the observations are transformed 
# by taking the natural logarithm of the values. 
# Data with this distribution is called log-normal.

# %%
for var in ['price','sqfeet','baths_per_beds','beds_per_sqfeet']:
    data[var] = np.log(data[var])

# %%
# check that data set does not contain null values in the engineered variables
[var for var in ['price','sqfeet','baths_per_beds','beds_per_sqfeet'] if data[var].isnull().sum() > 0]
# Out:
# []

# %%
# Removing rare labels

# %%
# let's capture the categorical variables in a list

cat_vars = ['region', 'type', 'laundry_options', 'parking_options', 'state']

# %%
frequent_ls = {
    'region': 
        ['denver', 'fayetteville', 'jacksonville', 'omaha / council bluffs', 'rochester'],
     'type': 
        ['apartment', 'condo', 'duplex', 'house', 'manufactured', 'townhouse'],
     'laundry_options': 
        ['laundry in bldg', 'laundry on site', 'w/d hookups', 'w/d in unit'],  
     'parking_options': 
        ['attached garage', 'carport', 'detached garage', 'off-street parking', 'street parking'],
     'state': 
        ['al', 'ar', 'az', 'ca', 'co', 'ct', 'fl', 'ga', 'ia', 'id', 'il', 'in', 'ks', 'ky', 'la', 
        'ma', 'md', 'mi', 'mn', 'ms', 'nc', 'nd', 'ne', 'nj', 'nm', 'nv', 'ny', 'oh']
}


for var in cat_vars:
    data[var] = np.where(data[var].isin(
        frequent_ls[var]), data[var], 'Rare')

# %%
# Encoding of categorical variables

# %%
# this function will assign discrete values to the strings of the variables,
# so that the smaller value corresponds to the category that shows the smaller
# mean house sale price


def replace_categories(data, var, target):

    # order the categories in a variable from that with the lowest
    # house sale price, to that with the highest
    ordered_labels = data.groupby([var])[target].mean().sort_values().index

    # create a dictionary of ordered categories to integer values
    ordinal_label = {k: i for i, k in enumerate(ordered_labels, 0)}
    #print(ordinal_label)

    # use the dictionary to replace the categorical strings by integers
    data[var] = data[var].map(ordinal_label)

# %%
for var in cat_vars:
    replace_categories(data, var, 'price')

# %%
# check absence of na in the train set
[var for var in data.columns if data[var].isnull().sum() > 0]
# Out:
# []

# %%
data.head(8)
# Out:
#                                                  url  region  \
# 1  https://bham.craigslist.org/apa/d/birmingham-w...     160
# 2  https://bham.craigslist.org/apa/d/birmingham-g...     160
# 3  https://bham.craigslist.org/apa/d/birmingham-f...     160
# 4  https://bham.craigslist.org/apa/d/birmingham-2...     160
# 5  https://bham.craigslist.org/apa/d/birmingham-s...     160
# 6  https://bham.craigslist.org/apa/d/birmingham-2...     160
# 8  https://bham.craigslist.org/apa/d/birmingham-n...     160
# 9  https://bham.craigslist.org/apa/d/birmingham-a...     160
#
#                     region_url     price  type    sqfeet  beds  baths  \
# 1  https://bham.craigslist.org  7.021084     5  7.184629     3      2
# 2  https://bham.craigslist.org  6.715383     5  7.032624     1      2
# 3  https://bham.craigslist.org  6.684612     5  6.831954     1      1
# 4  https://bham.craigslist.org  6.665684     5  6.953684     2      1
# 5  https://bham.craigslist.org  6.802395     5  7.168580     2      2
# 6  https://bham.craigslist.org  6.829794     5  7.207860     2      2
# 8  https://bham.craigslist.org  7.145984     5  7.052721     3      2
# 9  https://bham.craigslist.org  6.683361     5  6.555357     1      1
#
#    cats_allowed  dogs_allowed  ...  laundry_options  parking_options  \
# 1             1             1  ...                1                0
# 2             1             1  ...                1                1
# 3             1             1  ...                1                1
# 4             1             1  ...                1                1
# 5             1             1  ...                1                1
# 6             1             1  ...                1                1
# 8             1             1  ...                4                0
# 9             1             1  ...                4                0
#
#                                            image_url      lat     long  state  \
# 1  https://images.craigslist.org/00707_uRrY9CsNMC...  33.3755 -86.8045      9
# 2  https://images.craigslist.org/00h0h_b7Bdj1NLBi...  33.4226 -86.7065      9
# 3  https://images.craigslist.org/00808_6ghZ8tSRQs...  33.4226 -86.7065      9
# 4  https://images.craigslist.org/00y0y_21c0FOvUXm...  33.4226 -86.7065      9
# 5  https://images.craigslist.org/00606_g79izH5xxk...  33.4226 -86.7065      9
# 6  https://images.craigslist.org/00505_cAu36QXQV4...  33.4226 -86.7065      9
# 8  https://images.craigslist.org/00a0a_lTBiptw032...  33.4237 -86.8015      9
# 9  https://images.craigslist.org/00707_9dHoTSYoQn...  33.4237 -86.8015      9
#
#   premium_house  pets_allowed  beds_per_sqfeet  baths_per_beds
# 1             0             1        -6.086017       -0.405465
# 2             0             1        -7.032624        0.693147
# 3             0             1        -6.831954        0.000000
# 4             0             1        -6.260537       -0.693147
# 5             1             1        -6.475433        0.000000
# 6             1             1        -6.514713        0.000000
# 8             0             1        -5.954109       -0.405465
# 9             0             1        -6.555357        0.000000
#
# [8 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['url', 'region', 'region_url', 'price', 'type', 'sqfeet', 'beds',
#        'baths', 'cats_allowed', 'dogs_allowed', 'smoking_allowed',
#        'wheelchair_access', 'electric_vehicle_charge', 'comes_furnished',
#        'laundry_options', 'parking_options', 'image_url', 'lat', 'long',
#        'state', 'premium_house', 'pets_allowed', 'beds_per_sqfeet',
#        'baths_per_beds'],
#       dtype='object')

# %%
features = ['region', 'price', 'type', 'sqfeet', 'smoking_allowed', 'wheelchair_access', 
            'electric_vehicle_charge', 'comes_furnished', 'laundry_options', 'parking_options','lat', 'long', 
            'premium_house', 'pets_allowed', 'beds_per_sqfeet', 'baths_per_beds', ]

# %%
data_final = data[features].copy()

# %%
# for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# corraltion heat map
corr_matrix = data.corr()
# mask = np.zeros_like(corr_matrix, dtype=bool)
# mask[np.triu_indices_from(mask)]= True

fig, ax = plt.subplots(figsize=(25,25)) 

sns.heatmap(corr_matrix, 
            annot=True, 
            square=True,
            # fmt='.2g',
            mask=mask,
            # ax=ax
           ).set(
    title = 'Feature Correlation', xlabel = 'Columns', ylabel = 'Columns')

# ax.set_yticklabels(corr_matrix.columns, rotation = 0)
# ax.set_xticklabels(corr_matrix.columns)
# sns.set_style({'xtick.bottom': True}, {'ytick.left': True})
# Out:
# C:\Users\sksun\AppData\Local\Temp\ipykernel_14136\186601843.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
# [Text(0.5, 1.0, 'Feature Correlation'),
#  Text(0.5, 433.08159722222206, 'Columns'),
#  Text(283.08159722222223, 0.5, 'Columns')]

# %%
data_final.to_csv('dataRegression.csv', index=False)
